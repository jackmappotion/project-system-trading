# %%
"""
주식시장
환율

---
OHLCV 머장님 일수도 있다.

"""

# %%
import FinanceDataReader as fdr

# %%
fdr.__version__
# Out:
# '0.9.50'

# %%
krx_df = fdr.StockListing("KRX")
krx_df
# Out:
#         Code        ISU_CD      Name  Market   Dept   Close ChangeCode  \
# 0     005930  KR7005930003      삼성전자   KOSPI          69600          2
# 1     373220  KR7373220003  LG에너지솔루션   KOSPI         402000          1
# 2     000660  KR7000660001    SK하이닉스   KOSPI         125800          1
# 3     207940  KR7207940008  삼성바이오로직스   KOSPI         705000          2
# 4     005935  KR7005931001     삼성전자우   KOSPI          56600          1
# ...      ...           ...       ...     ...    ...     ...        ...
# 2760  021045  KR7021041009    대호특수강우  KOSDAQ  중견기업부    7270          2
# 2761  288490  KR7288490006     나라소프트   KONEX  일반기업부      59          3
# 2762  245450  KR7245450002    씨앤에스링크   KONEX  일반기업부    1589          2
# 2763  308700  KR7308700004       테크엔   KONEX  일반기업부     500          1
# 2764  322190  KR7322190000        베른   KONEX  일반기업부     111          5
#
#       Changes  ChagesRatio    Open    High     Low    Volume        Amount  \
# ...

# %%
df = fdr.DataReader('215600', '2023')
df.tail(10)
# Out:
#             Open  High   Low  Close  Volume    Change
# Date
# 2023-10-23  5030  5080  4610   4630  895143 -0.074000
# 2023-10-24  4700  4840  4540   4810  631240  0.038877
# 2023-10-25  4810  4835  4525   4595  749724 -0.044699
# 2023-10-26  4520  4570  4425   4535  453774 -0.013058
# 2023-10-27  4595  4775  4500   4665  559215  0.028666
# 2023-10-30  4570  4685  4485   4540  465747 -0.026795
# 2023-10-31  4555  4565  4340   4345  520849 -0.042952
# 2023-11-01  4345  4450  4295   4325  325887 -0.004603
# 2023-11-02  4415  4490  4380   4430  309408  0.024277
# 2023-11-03  4450  4495  4365   4470  285392  0.009029

# %%
df = fdr.DataReader("JPY/KRW", "1995")
